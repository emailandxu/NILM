# %%
from nilm.nn.main import *
# Out:
# (8010973, 1)
# (1600000, 1)
# (8074277, 1)
# (1600000, 1)
# (7908322, 1)
# <built-in method mean of numpy.ndarray object at 0x7f9a88314e40>
# (8054586, 1)
# (1600000, 1)
# (7945298, 1)
# (1600000, 1)
# /mnt/hdd/NILM/nilmvenv/lib/python3.6/site-packages/keras/engine/training.py:1972: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/2
# 6250/6250 [==============================] - 65s 10ms/step - loss: 0.0700 - acc: 0.9217 - val_loss: 0.0417 - val_acc: 0.9491
# Epoch 2/2
# 6250/6250 [==============================] - 60s 10ms/step - loss: 0.0475 - acc: 0.9274 - val_loss: 0.0409 - val_acc: 0.9411
